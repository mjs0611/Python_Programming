# %%
import numpy as np
import pandas as pd

# %%
# Series : 1차원 형태의 배열과 비슷한 데이터 타입
# Series에는 한가지 타입의 값들만 저장가능
# DataFrame : 2차원 형태의 배열과 비슷한 데이터 타입
# DataFrame의 각 컬럼에는 같은 타입의 값들이 저장되어야 함
# Series들로 이루어진 집합
# Series와 DataFrame이 numpy.ndarray와 다른 점은
# 인덱스를 지정할 수 있다는 것

# %%
s = pd.Series([1, 10, 5, 9])
print(s)
# Out:
# 0     1
# 1    10
# 2     5
# 3     9
# dtype: int64

# %%
print(s[0])
# Out:
# 1

# %%
print(s[0:2])
# Out:
# 0     1
# 1    10
# dtype: int64

# %%
print(s[[True, False, True, False]])
# Out:
# 0    1
# 2    5
# dtype: int64

# %%
s = pd.Series(data=[100, 90, 70],
              index=["서울", "경기", "인천"])
print(s)
print(s.shape)   # 1-D(1차원)
# Out:
# 서울    100
# 경기     90
# 인천     70
# dtype: int64
# (3,)

# %%
print(s["인천"])
# Out:
# 70

# %%
# Series.loc[] : 레이블 기반의 인덱스
# Series.iloc[] : 정수 위치 기반의 인덱스
print(s.loc["서울"])
print(s.iloc[0])
# Out:
# 100
# 100

# %%
print(s.loc["경기":"인천"])   # 경기 <= label <= 인천
print(s.iloc[1:3])   # start <= i < end
# Out:
# 경기    90
# 인천    70
# dtype: int64
# 경기    90
# 인천    70
# dtype: int64

# %%
s = pd.Series([1, 3, 5, 7, 9, 11])
print(s)
# Out:
# 0     1
# 1     3
# 2     5
# 3     7
# 4     9
# 5    11
# dtype: int64

# %%
print(s.loc[1:3])
# Out:
# 1    3
# 2    5
# 3    7
# dtype: int64

# %%
print(s.iloc[1:3])
# Out:
# 1    3
# 2    5
# dtype: int64

# %%
df = pd.DataFrame({"번호": [1, 2, 3],
                   "키": [170, 175, 160],
                   "몸무게": [75, 65, 60]})
df.loc[0:1]
# Out:
#    번호    키  몸무게
# 0   1  170   75
# 1   2  175   65

# %%
df.iloc[0:1]
# Out:
#    번호    키  몸무게
# 0   1  170   75
