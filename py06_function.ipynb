# %%
print("안녕하세요")
# print() : () 안의 내용을 화면 출력하는 기능
# Out:
# 안녕하세요

# %%
numbers = [1, 3, 5, 7]
print(len(numbers))
# len(obj) : obj의 길이(length)를 계산해 봔환해 주는 기능
length = len(numbers)
length
# Out:
# 4

# %%
s = sum(numbers)   # 함수 호출(call, invoke)
s
# Out:
# 16

# %%
# 함수(function) : 자주 사용되는 기능들을 작성한 코드 블록
# 함수를 정의하고, 필요한 곳에서 함수를 불러서(호출해서) 사용

# %%
id_numbers = id(numbers)
id_numbers
# Out:
# 140009353563080

# %%
# 함수 정의
def sum_of_list(num_list):
  """
  숫자들의 리스트 (num_list)를 전달받아서, 리스트의 모든 원소들의 합(summation)을 리턴(return, 반환)하는 함수

  :param num_list : 숫자들의 리스트
  :return : 리스트 안의 모든 원소들의 합
  """
  sum_ = 0
  for n in num_list:
    sum_ += n
  return sum_

# %%
int_array = [1, 2, 3, 4, 5]
s = sum_of_list(int_array)
s
# Out:
# 15

# %%
# 함수 - 기능
# argument - 함수를 호출하는 곳에서 함수에게 전달하는 값
# parameter - 함수를 정의하는 곳에서, 전달받은 값을 저장하기 위해 선언하는 변수
# return(반환) 값 - 함수가 모든 기능을 다 한 후, 함수를 호출한 곳으로 되돌려주는 값

# %%
# 숫자들의 리스트를 전달받아서, 그 숫자들의 평균을 리턴하는 함수
def average(num_list):
  n = len(num_list)   # 리스트의 원소의 개수
  s = sum_of_list(num_list)   # 리스트의 모든 원소들의 합
  return s/n

# %%
avg = average([1, 2, 3, 4, 5])
avg
# Out:
# 3.0
